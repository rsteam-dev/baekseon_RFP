# %% [markdown]
# ### Import Libreries

# %%
#main Libraries
import pandas as pd
from pandas import DataFrame
import numpy as np
#visualisation libreries 
from matplotlib import pyplot as plt
# %matplotlib inline

# Multi Label Pkgs
from skmultilearn.problem_transform import BinaryRelevance 
from skmultilearn.problem_transform import ClassifierChain 
from skmultilearn.problem_transform import LabelPowerset
from skmultilearn.adapt import MLkNN
from sklearn import metrics
#Library for training
from sklearn.model_selection import train_test_split
#from sklearn.metrics import accuracy_score

# %% [markdown]
# # Working on the data

# %%
# import data with panda
#data = pd.read_csv("pkt_radish.csv", engine='python', index_col = 0)
data = pd.read_csv("data_agriculture2.csv", engine='python', index_col = 0)
data.describe()
# Out:
#          dayAvgRhm     dayAvgTa     dayAvgWs     dayMaxTa    dayMinRhm  \
# count  5673.000000  5673.000000  5673.000000  5673.000000  5673.000000
# mean     45.559669     8.763617     1.088666    11.959633    29.640578
# std      34.274971     9.933435     1.239796    11.568598    25.224696
# min       0.000000   -14.000000     0.000000    -9.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%      59.000000     6.000000     1.000000    10.000000    32.000000
# 75%      73.000000    18.000000     2.000000    23.000000    50.000000
# max     100.000000    32.000000    11.000000    39.000000    99.000000
#
#           daySumRn     daySumSs
# count  5673.000000  5673.000000
# mean      1.991363     2.433104
# std      10.208532     3.802857
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       0.000000     5.000000
# max     265.000000    13.000000

# %% [markdown]
# ## Data understanding throught visualisation

# %% [markdown]
# ## Cleaning dataset

# %%
# making a copy of the dataset in what we will work 
data_c = data.copy()

# %%
#check if there sis null values in dataset
data_c.isnull().sum().sum()
# Out:
# 7604

# %%
# reemoving all empty data 
data_c = data_c.dropna(how='any')

# %%
data_c
# Out:
#             date area  dayAvgRhm  dayAvgTa  dayAvgWs  dayMaxTa  dayMinRhm  \
# idx
# 2       1/5/2017   춘천         74         2         1         7         52
# 4      1/27/2017   춘천         62        -1         2         2         33
# 5       1/7/2017   춘천         89         0         0         7         54
# 7       1/3/2017   춘천         78         0         1         7         31
# 9       1/6/2017   춘천         77         3         0        10         41
# ...          ...  ...        ...       ...       ...       ...        ...
# 5669  12/18/2020   제주         57         7         3        10         42
# 5670   12/6/2020   제주         60         8         1        11         48
# 5671  12/31/2020   제주         68         2         6         4         49
# 5672  12/11/2020   제주         68        11         1        12         57
# 5673   12/8/2020   제주         63         8         3        10         54
#
#       daySumRn  daySumSs paCropName paCropSpeId
# idx
# 2            0         0         들깨    PA100101
# 4            5         8         들깨    PA100101
# 5            0         4         들깨    PA100101
# 7            0         5         들깨    PA100101
# 9            0         7         들깨    PA100101
# ...        ...       ...        ...         ...
# 5669         0         1         쪽파    PA290101
# 5670         0         8         쪽파    PA290101
# 5671         3         0         쪽파    PA290101
# 5672         0         0         쪽파    PA290101
# 5673         0         3         쪽파    PA290101
#
# [3772 rows x 11 columns]

# %%
#checking if there still a null value in the dataset
data_c.isnull().sum()
# Out:
# date           0
# area           0
# dayAvgRhm      0
# dayAvgTa       0
# dayAvgWs       0
# dayMaxTa       0
# dayMinRhm      0
# daySumRn       0
# daySumSs       0
# paCropName     0
# paCropSpeId    0
# dtype: int64

# %%
# checking data type 
for dtype in data.dtypes.iteritems(): 
    print(dtype)
# Out:
# ('date', dtype('O'))
# ('area', dtype('O'))
# ('dayAvgRhm', dtype('int64'))
# ('dayAvgTa', dtype('int64'))
# ('dayAvgWs', dtype('int64'))
# ('dayMaxTa', dtype('int64'))
# ('dayMinRhm', dtype('int64'))
# ('daySumRn', dtype('int64'))
# ('daySumSs', dtype('int64'))
# ('paCropName', dtype('O'))
# ('paCropSpeId', dtype('O'))

# %% [markdown]
# ## Feature Modelisation

# %%
data_c.columns
# Out:
# Index(['date', 'area', 'dayAvgRhm', 'dayAvgTa', 'dayAvgWs', 'dayMaxTa',
#        'dayMinRhm', 'daySumRn', 'daySumSs', 'paCropName', 'paCropSpeId'],
#       dtype='object')

# %%
data_c.shape
# Out:
# (3772, 11)

# %%
#transform string to day time 
data_c['date'] = pd.to_datetime(data_c['date'], errors = 'coerce')
data_c.date.head()
# Out:
# idx
# 2   2017-01-05
# 4   2017-01-27
# 5   2017-01-07
# 7   2017-01-03
# 9   2017-01-06
# Name: date, dtype: datetime64[ns]

# %%
# creating separate columns for month and day because
data_c['month'] = data_c['date'].dt.month
data_c['day'] = data_c['date'].dt.day
data_c.head(10000)
# Out:
#            date area  dayAvgRhm  dayAvgTa  dayAvgWs  dayMaxTa  dayMinRhm  \
# idx
# 2    2017-01-05   춘천         74         2         1         7         52
# 4    2017-01-27   춘천         62        -1         2         2         33
# 5    2017-01-07   춘천         89         0         0         7         54
# 7    2017-01-03   춘천         78         0         1         7         31
# 9    2017-01-06   춘천         77         3         0        10         41
# ...         ...  ...        ...       ...       ...       ...        ...
# 5669 2020-12-18   제주         57         7         3        10         42
# 5670 2020-12-06   제주         60         8         1        11         48
# 5671 2020-12-31   제주         68         2         6         4         49
# 5672 2020-12-11   제주         68        11         1        12         57
# 5673 2020-12-08   제주         63         8         3        10         54
#
#       daySumRn  daySumSs paCropName paCropSpeId  month  day
# idx
# 2            0         0         들깨    PA100101      1    5
# 4            5         8         들깨    PA100101      1   27
# 5            0         4         들깨    PA100101      1    7
# 7            0         5         들깨    PA100101      1    3
# 9            0         7         들깨    PA100101      1    6
# ...        ...       ...        ...         ...    ...  ...
# 5669         0         1         쪽파    PA290101     12   18
# 5670         0         8         쪽파    PA290101     12    6
# 5671         3         0         쪽파    PA290101     12   31
# 5672         0         0         쪽파    PA290101     12   11
# 5673         0         3         쪽파    PA290101     12    8
#
# [3772 rows x 13 columns]

# %%
data_c.groupby('month').size()
# Out:
# month
# 1     355
# 2     294
# 3     332
# 4     312
# 5     316
# 6     283
# 7     302
# 8     300
# 9     289
# 10    325
# 11    326
# 12    338
# dtype: int64

# %%
data_c.groupby('day').size()
# Out:
# day
# 1     131
# 2     132
# 3     130
# 4     133
# 5     129
# 6     131
# 7     126
# 8     130
# 9     133
# 10    125
# 11    123
# 12    128
# 13    128
# 14    123
# 15    119
# 16    125
# 17    122
# 18    126
# 19    127
# 20    130
# 21    132
# 22    119
# 23    119
# 24    121
# 25    120
# 26    121
# 27    115
# 28    118
# 29    103
# 30     94
# 31     59
# dtype: int64

# %%
#Create another column that will contains the numiric values of area
data_c['area_id'] = data_c['area']

# %%
data_c.loc[data['area'] == '평택', 'area_id'] = 0   ##평택 == 1
data_c.loc[data['area'] == '춘천', 'area_id'] = 1
data_c.loc[data['area'] == '제주', 'area_id'] = 2

# %%
#Create another column that will contains the numiric values of species
#data_c['crop_id'] = data_c['paCropName']

# %%
del data_c['paCropSpeId']

# %%
del data_c['paCropName']

# %%
#data_c.loc[data['paCropName'] == '무', 'crop_id'] = 1   ##무 == 1

# %%
data_c.head()
# Out:
#           date area  dayAvgRhm  dayAvgTa  dayAvgWs  dayMaxTa  dayMinRhm  \
# idx
# 2   2017-01-05   춘천         74         2         1         7         52
# 4   2017-01-27   춘천         62        -1         2         2         33
# 5   2017-01-07   춘천         89         0         0         7         54
# 7   2017-01-03   춘천         78         0         1         7         31
# 9   2017-01-06   춘천         77         3         0        10         41
#
#      daySumRn  daySumSs  month  day area_id
# idx
# 2           0         0      1    5       1
# 4           5         8      1   27       1
# 5           0         4      1    7       1
# 7           0         5      1    3       1
# 9           0         7      1    6       1

# %% [markdown]
# #### Creating a binary targets for classification

# %%
# For 무 we make the table true for certain contion
# data_c['can_produce'] = (data_c.paCropName.isin(['무']) & (data_c.dayAvgTa < 21) & (data_c.dayAvgTa > 14))
data_c['can_produce'] = ((data_c.dayAvgTa < 21) & (data_c.dayAvgTa > 14))

# %%
#transform the table in binary
data_c['target_value'] = (data_c['can_produce']).astype('int')
data_c.head(30)
# Out:
#           date area  dayAvgRhm  dayAvgTa  dayAvgWs  dayMaxTa  dayMinRhm  \
# idx
# 2   2017-01-05   춘천         74         2         1         7         52
# 4   2017-01-27   춘천         62        -1         2         2         33
# 5   2017-01-07   춘천         89         0         0         7         54
# 7   2017-01-03   춘천         78         0         1         7         31
# 9   2017-01-06   춘천         77         3         0        10         41
# 10  2017-01-01   춘천         93         0         0         3         72
# 11  2017-01-04   춘천         79         1         0         9         35
# 12  2017-01-18   춘천         72        -3         0         3         53
# 13  2017-01-02   춘천         88         2         1         8         56
# 15  2017-01-20   춘천         71        -2         1         0         49
# 16  2017-01-08   춘천         78         5         1        10         51
# 17  2017-01-30   춘천         73        -2         1         0         56
# 20  2017-01-10   춘천         54        -2         2         3         18
# 21  2017-01-21   춘천         79        -5         1         0         55
# 22  2017-01-31   춘천         77        -7         0         0         36
# 24  2017-01-22   춘천         49        -7         2        -3         35
# 25  2017-01-11   춘천         42        -4         1         1         25
# 26  2017-01-19   춘천         77        -2         0         4         39
# 27  2017-01-13   춘천         43        -4         2         0         24
# 29  2017-01-12   춘천         47        -2         2         2         20
# 30  2017-01-28   춘천         69        -5         0         2         22
# 31  2017-01-24   춘천         65        -9         1         0         24
# 32  2017-01-07   춘천         89         0         0         7         54
# 33  2017-01-21   춘천         79        -5         1         0         55
# 34  2017-01-13   춘천         43        -4         2         0         24
# 35  2017-01-04   춘천         79         1         0         9         35
# 37  2017-01-29   춘천         88         0         0         1         67
# 38  2017-01-30   춘천         73        -2         1         0         56
# 39  2017-01-01   춘천         93         0         0         3         72
# 40  2017-01-22   춘천         49        -7         2        -3         35
#
#      daySumRn  daySumSs  month  day area_id  can_produce  target_value
# idx
# 2           0         0      1    5       1        False             0
# 4           5         8      1   27       1        False             0
# 5           0         4      1    7       1        False             0
# 7           0         5      1    3       1        False             0
# 9           0         7      1    6       1        False             0
# 10          0         1      1    1       1        False             0
# 11          0         7      1    4       1        False             0
# 12          0         2      1   18       1        False             0
# 13          0         3      1    2       1        False             0
# 15          0         3      1   20       1        False             0
# 16          0         3      1    8       1        False             0
# 17          0         1      1   30       1        False             0
# 20          0         8      1   10       1        False             0
# 21          0         6      1   21       1        False             0
# 22          0         7      1   31       1        False             0
# 24          0         8      1   22       1        False             0
# 25          0         8      1   11       1        False             0
# 26          0         5      1   19       1        False             0
# 27          0         5      1   13       1        False             0
# 29          0         8      1   12       1        False             0
# 30          0         7      1   28       1        False             0
# 31          0         8      1   24       1        False             0
# 32          0         4      1    7       1        False             0
# 33          0         6      1   21       1        False             0
# 34          0         5      1   13       1        False             0
# 35          0         7      1    4       1        False             0
# 37          7         0      1   29       1        False             0
# 38          0         1      1   30       1        False             0
# 39          0         1      1    1       1        False             0
# 40          0         8      1   22       1        False             0

# %% [markdown]
# ### Function to see prevalence

# %%
def calc_prevalence(y): 
    return (sum(y)/len(y))

# %%
calc_prevalence(data_c.target_value.values)
# Out:
# 0.19803817603393425

# %%
data_c.groupby('dayAvgRhm').mean()
# Out:
#             dayAvgTa  dayAvgWs   dayMaxTa  dayMinRhm   daySumRn   daySumSs  \
# dayAvgRhm
# 0           0.000000  0.000000   0.000000  16.083333   0.000000   0.750000
# 23         11.000000  3.000000  15.000000  13.000000   0.000000   0.000000
# 26          7.000000  2.000000  12.000000  14.500000   0.000000   4.500000
# 28         11.000000  2.000000  17.000000  12.000000   0.000000  11.000000
# 29          7.000000  2.000000  12.000000  15.000000   0.000000   0.000000
# ...              ...       ...        ...        ...        ...        ...
# 96         19.785714  2.142857  22.285714  81.285714  38.285714   0.000000
# 97         22.307692  0.923077  24.846154  83.000000  40.769231   0.076923
# 98         21.200000  1.400000  23.000000  86.400000  43.700000   0.000000
# 99         21.866667  0.600000  24.066667  89.600000  62.133333   0.000000
# 100        22.285714  1.000000  23.857143  95.714286  56.857143   0.000000
#
#               month        day  can_produce  target_value
# dayAvgRhm
# 0          7.916667  18.750000     0.000000      0.000000
# 23         4.000000  12.000000     0.000000      0.000000
# 26         3.000000  13.500000     0.500000      0.500000
# 28         4.000000  12.000000     0.000000      0.000000
# 29         3.000000  28.000000     0.000000      0.000000
# ...             ...        ...          ...           ...
# 96         6.714286  13.071429     0.285714      0.285714
# 97         7.230769  15.692308     0.230769      0.230769
# 98         7.300000  15.000000     0.300000      0.300000
# 99         7.000000  17.133333     0.133333      0.133333
# 100        7.714286   9.285714     0.142857      0.142857
#
# [75 rows x 10 columns]

# %%
data_c.groupby('month').mean()
# Out:
#        dayAvgRhm   dayAvgTa  dayAvgWs   dayMaxTa  dayMinRhm  daySumRn  \
# month
# 1      66.400000   1.692958  1.771831   5.692958  44.177465  0.963380
# 2      61.693878   2.431973  1.734694   7.159864  37.115646  1.023810
# 3      61.590361   7.596386  1.891566  13.126506  35.539157  1.250000
# 4      60.336538  12.400641  1.923077  18.086538  34.291667  1.894231
# 5      66.101266  18.066456  1.721519  23.797468  40.601266  2.177215
# 6      71.897527  22.035336  1.533569  27.296820  47.540636  3.349823
# 7      79.029801  24.993377  1.400662  28.963576  59.798013  6.956954
# 8      77.573333  26.236667  1.510000  30.440000  56.756667  9.990000
# 9      76.314879  20.955017  1.491349  25.570934  51.851211  5.411765
# 10     70.960000  14.996923  1.418462  20.138462  44.892308  1.590769
# 11     68.079755   8.398773  1.398773  13.414110  42.671779  1.558282
# 12     64.473373   2.890533  1.795858   6.769231  42.017751  0.961538
#
#        daySumSs        day  can_produce  target_value
# month
# 1      2.633803  15.701408     0.002817      0.002817
# 2      3.608844  14.530612     0.006803      0.006803
# 3      3.972892  15.509036     0.042169      0.042169
# 4      4.746795  14.967949     0.275641      0.275641
# 5      4.753165  15.341772     0.778481      0.778481
# 6      4.554770  14.795053     0.208481      0.208481
# 7      3.264901  15.026490     0.033113      0.033113
# 8      4.073333  16.010000     0.026667      0.026667
# 9      3.377163  15.546713     0.418685      0.418685
# 10     3.606154  15.766154     0.501538      0.501538
# 11     3.217791  15.150307     0.107362      0.107362
# 12     2.399408  15.257396     0.005917      0.005917

# %% [markdown]
# ### ploting to see which month is the best for planting

# %%
pd.crosstab(data_c.month,data_c.target_value).plot(kind='bar')
plt.title('Best Month to plant 무')
plt.xlabel('Month')
plt.ylabel('can product')
plt.savefig('can_produce_per_month')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47924 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47924 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
pd.crosstab(data_c.area_id,data_c.target_value).plot(kind='bar')
plt.title('Best place for  무')
plt.xlabel('Area')
plt.ylabel('can product')
plt.savefig('can_produce_per_month')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47924 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47924 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## split samples : 70% train and 30% validation

# %%
data_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3772 entries, 2 to 5673
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          3772 non-null   datetime64[ns]
#  1   area          3772 non-null   object
#  2   dayAvgRhm     3772 non-null   int64
#  3   dayAvgTa      3772 non-null   int64
#  4   dayAvgWs      3772 non-null   int64
#  5   dayMaxTa      3772 non-null   int64
#  6   dayMinRhm     3772 non-null   int64
#  7   daySumRn      3772 non-null   int64
#  8   daySumSs      3772 non-null   int64
#  9   month         3772 non-null   int64
#  10  day           3772 non-null   int64
#  11  area_id       3772 non-null   object
#  12  can_produce   3772 non-null   bool
#  13  target_value  3772 non-null   int32
# dtypes: bool(1), datetime64[ns](1), int32(1), int64(9), object(2)
# memory usage: 401.5+ KB

# %%
# shuffle the samples
data_c = data_c.sample(n = len(data_c), random_state = 42)
data_c = data_c.reset_index(drop = True)
data_valid = data_c.sample(frac = 0.3, random_state = 42)
data_train = data_c.drop(data_valid.index)

# %%
#calcul Prevalence
print('Valid prevalence(n = %d):%.3f'%(len(data_valid), calc_prevalence(data_valid.target_value.values)))
print('Train prevalence(n = %d):%.3f'%(len(data_train), calc_prevalence(data_train.target_value.values)))
# Out:
# Valid prevalence(n = 1132):0.228
# Train prevalence(n = 2640):0.185

# %%
data_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3772 entries, 0 to 3771
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          3772 non-null   datetime64[ns]
#  1   area          3772 non-null   object
#  2   dayAvgRhm     3772 non-null   int64
#  3   dayAvgTa      3772 non-null   int64
#  4   dayAvgWs      3772 non-null   int64
#  5   dayMaxTa      3772 non-null   int64
#  6   dayMinRhm     3772 non-null   int64
#  7   daySumRn      3772 non-null   int64
#  8   daySumSs      3772 non-null   int64
#  9   month         3772 non-null   int64
#  10  day           3772 non-null   int64
#  11  area_id       3772 non-null   object
#  12  can_produce   3772 non-null   bool
#  13  target_value  3772 non-null   int32
# dtypes: bool(1), datetime64[ns](1), int32(1), int64(9), object(2)
# memory usage: 372.2+ KB

# %%
# table of features
features2use = ['month', 'area_id'] ##, 'dayMaxTa', 'dayAvgTa', 'dayAvgRhm']

# %%
X_train = data_train[features2use].values
X_valid = data_valid[features2use].values

y_train = data_train['target_value'].values
y_valid = data_valid['target_value'].values

print('training shapes: ', X_train.shape, y_train.shape)
print('valid shapes: ', X_valid.shape, y_valid.shape)
# Out:
# training shapes:  (2640, 2) (2640,)
# valid shapes:  (1132, 2) (1132,)

# %%
#Baseline Mean Error
from sklearn.metrics import mean_absolute_error
y_pred = [y_train.mean()] * len(y_train)

print('BaseLine MAE: ', round(mean_absolute_error(y_train, y_pred), 5))
# Out:
# BaseLine MAE:  0.30184

# %% [markdown]
# ## Model with Logistic regression

# %%
data_c
# Out:
#            date area  dayAvgRhm  dayAvgTa  dayAvgWs  dayMaxTa  dayMinRhm  \
# 0    2017-10-21   춘천         79        13         0        23         33
# 1    2019-10-03   평택         85        22         2        27         57
# 2    2020-09-09   제주         68        25         2        28         45
# 3    2019-02-05   제주         57         9         2        13         47
# 4    2018-05-06   평택         94        15         1        19         65
# ...         ...  ...        ...       ...       ...       ...        ...
# 3767 2020-07-21   춘천         74        25         1        31         39
# 3768 2017-02-12   평택         66        -1         2         3         38
# 3769 2019-10-04   춘천         85        20         0        26         59
# 3770 2020-03-07   제주         84        10         2        11         64
# 3771 2019-01-19   제주         74         8         2        12         61
#
#       daySumRn  daySumSs  month  day area_id  can_produce  target_value
# 0            0         7     10   21       1        False             0
# 1           16         0     10    3       0        False             0
# 2            0         7      9    9       2        False             0
# 3            0         8      2    5       2        False             0
# 4           24         0      5    6       0         True             1
# ...        ...       ...    ...  ...     ...          ...           ...
# 3767         0         8      7   21       1        False             0
# 3768         0         0      2   12       0        False             0
# 3769         0         6     10    4       1         True             1
# 3770         8         0      3    7       2        False             0
# 3771         1         1      1   19       2        False             0
#
# [3772 rows x 14 columns]

# %%
data_c.to_csv(r'C:\Users\user\Desktop\RS_Team Project\Bu_smart_fram\data and code\soil_property\temperature.csv', index = False, header=True, encoding='utf-8')

# %%
#fit a logistic regression in on the training dataset 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score 

model = LogisticRegression(solver='lbfgs')
#fit
model.fit(X_train, y_train)

#make predictions

y_pred = model.predict(X_valid)
print(y_pred)
#evaluatin
# Out:
# [0 0 0 ... 0 0 0]

# %%
print('Accuracy: ', metrics.accuracy_score(y_valid, y_pred))
plt.show()
# Out:
# Accuracy:  0.7720848056537103

# %%
model = LogisticRegression(solver='lbfgs')
#fit
model.fit(X_train, y_train)
#make predictions
model.fit(X_train, y_train)
new_input = [[5, 2]]   ###'month', 'area_id', 'dayMaxTa', 'dayAvgTa', 'dayAvgRhm'

new_output = model.predict(new_input)
#evaluatin 
#acc = accuracy_score(y_train, yhat)
#input

print(new_output)
#print(acc)
# Out:
# [0]

# %% [markdown]
# ### Confusion machine
# confusion_matrix = pd.crosstab(y_valid, y_pred, rownames=['Actual'], colnames=['Predicted'])
# sns.heatmap(confusion_matrix, annot=True)

# %% [markdown]
# ## Model with random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(max_depth = 5, n_estimators=100, random_state = 42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, random_state=42)

# %% [markdown]
# #### Prediction

# %%
y_train_preds = rf.predict_proba(X_train)[:,1]
y_valid_preds = rf.predict_proba(X_valid)[:,1]

# %% [markdown]
# #### Performance evalution

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score
def calc_specificity(y_actual, y_pred, thresh):
 # calculates specificity
 return sum((y_pred < thresh) & (y_actual == 0)) /sum(y_actual ==0)

def print_report(y_actual, y_pred, thresh):  
    auc = roc_auc_score(y_actual, y_pred)
    accuracy = accuracy_score(y_actual, (y_pred > thresh))
    recall = recall_score(y_actual, (y_pred > thresh))
    precision = precision_score(y_actual, (y_pred > thresh))
    specificity = calc_specificity(y_actual, y_pred, thresh) 
    print('AUC:%.3f'%auc)
    print('accuracy:%.3f'%accuracy)
    print('recall:%.3f'%recall)
    print('precision:%.3f'%precision)
    print('specificity:%.3f'%specificity)
    print('prevalence:%.3f'%calc_prevalence(y_actual))
    print(' ')
    return auc, accuracy, recall, precision, specificity

# %%
thresh = 0.201
print('random Forest')
print('trining')
print_report(y_train, y_train_preds, thresh);
print('validation: ')
print_report(y_valid, y_valid_preds, thresh);
# Out:
# random Forest
# trining
# AUC:0.905
# accuracy:0.842
# recall:0.798
# precision:0.550
# specificity:0.852
# prevalence:0.185
#
# validation:
# AUC:0.904
# accuracy:0.838
# recall:0.779
# precision:0.615
# specificity:0.856
# prevalence:0.228

# %% [markdown]
# ### Testing with personal entries

# %%
my_input = [[1, 2]]  ###'month', ''Area'
my_output = rf.predict(my_input)
x = rf.predict(X_valid)
print(my_input, my_output)
print(x)
# Out:
# [[1, 2]] [0]
# [0 0 0 ... 0 0 1]

# %% [markdown]
# ### Ploting

# %%
### ROC curve 
from sklearn.metrics import roc_curve

fpr_train, tpr_train, thresholds_train = roc_curve(y_train, y_train_preds)
auc_train = roc_auc_score(y_train, y_train_preds)
fpr_valid, tpr_valid, thresholds_valid = roc_curve(y_valid, y_valid_preds)
auc_valid = roc_auc_score(y_valid, y_valid_preds)
plt.plot(fpr_train, tpr_train, 'r-',label ='Train AUC:%.3f'%auc_train)
plt.plot(fpr_valid, tpr_valid, 'b-',label ='Valid AUC:%.3f'%auc_valid)
plt.plot([0,1],[0,1], 'k')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %% [markdown]
# ### investigating features for better usage

# %%
feature_importances = pd.DataFrame(rf.feature_importances_,
 index = features2use,
 columns=['importance']).sort_values('importance',ascending=False)

num = min([50,len(features2use)])
ylocs = np.arange(num)
# get the feature importance for top num and sort in reverse order
values_to_plot = feature_importances.iloc[:num].values.ravel()[::-1]
feature_labels = list(feature_importances.iloc[:num].index)[::-1]
plt.figure(num=None, figsize=(6, 6), dpi=80, facecolor='w', edgecolor='k');
plt.barh(ylocs, values_to_plot, align = 'center')
plt.ylabel('Features')
plt.xlabel('Importance Score')
plt.title('Feature Importance Score — Random Forest')
plt.yticks(ylocs, feature_labels)
plt.show()

# %% [markdown]
# ### Try to create random input to see if the model works

# %%
#Dependancies and their versions

# %%
import pip
for i in pip.get_installed_distributions(local_only=True):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-76e0c5abac83> in <module>
#       1 import pip
# ----> 2 for i in pip.get_installed_distributions(local_only=True):
#       3     print(i)
#
# AttributeError: module 'pip' has no attribute 'get_installed_distributions'

# %%
import types
def imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            yield val.__name__
list(imports())
# Out:
# ['builtins',
#  'builtins',
#  'pandas',
#  'numpy',
#  'matplotlib.pyplot',
#  'sklearn.metrics',
#  'pip',
#  'types']

# %%
# %load_ext watermark
# %watermark -v -m -p pandas,numpy
print(" ")
# %watermark -u -n -t -z
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Python implementation: CPython
# Python version       : 3.7.10
# IPython version      : 7.21.0
#
# pandas: 1.2.3
# numpy : 1.16.2
#
# Compiler    : MSC v.1916 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 142 Stepping 10, GenuineIntel
# CPU cores   : 8
# Architecture: 64bit
#
#
# Last updated: Wed Apr 14 2021 15:16:28Korea Standard Time

# %%
sklearn.metrics_version = sklearn.metrics.__version__

print(sklearn_version)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-54c8d4707932> in <module>
# ----> 1 sklearn.metrics_version = sklearn.metrics.__version__
#       2
#       3 print(sklearn_version)
#
# NameError: name 'sklearn' is not defined
